# %% [markdown]
# <a href="https://colab.research.google.com/github/zapata-git/Evaluacion-de-seguros-de-vida-para-Prudential-/blob/main/Pipeline1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Instalación de librerías:

# %%
# !pip install pandas
# !pip install numpy
# !pip install scikit-learn
# !pip install matplotlib
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# # **Conexión con Google Drive:**

# %%
from google.colab import drive
import pandas as pd
import os

# Montar Drive
drive.mount('/content/drive')

folder_path = '/content/drive/MyDrive/Proyecto_IA'

# Lista de todos los archivos y carpetas en la ruta de la carpeta
files = os.listdir(folder_path)

# Imprimir la lista de archivos
print(files)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ['sample_submission.csv', 'train.csv', 'test.csv']

# %% [markdown]
# # **Carga de datos:**

# %%
# Ruta donde se encuentran los datos en tu Drive
ruta = '/content/drive/MyDrive/Proyecto_IA/'

# Cargar los datos de entrenamiento (train)
train = pd.read_csv(ruta + 'train.csv')

# Cargar los datos de prueba (test)
test = pd.read_csv(ruta + 'test.csv')

# %% [markdown]
# # **Análisis exploratorio de datos (EDA)**

# %%
train_data = pd.read_csv('/content/drive/MyDrive/Proyecto_IA/train.csv')
test_data = pd.read_csv('/content/drive/MyDrive/Proyecto_IA/test.csv')
train_data.head()
# Out:
#    Id  Product_Info_1 Product_Info_2  Product_Info_3  Product_Info_4  \
# 0   2               1             D3              10        0.076923
# 1   5               1             A1              26        0.076923
# 2   6               1             E1              26        0.076923
# 3   7               1             D4              10        0.487179
# 4   8               1             D2              26        0.230769
#
#    Product_Info_5  Product_Info_6  Product_Info_7   Ins_Age        Ht  ...  \
# 0               2               1               1  0.641791  0.581818  ...
# 1               2               3               1  0.059701  0.600000  ...
# 2               2               3               1  0.029851  0.745455  ...
# 3               2               3               1  0.164179  0.672727  ...
# 4               2               3               1  0.417910  0.654545  ...
#
#    Medical_Keyword_40  Medical_Keyword_41  Medical_Keyword_42  \
# ...

# %%
#Verificamos la cantidad de registros y columnas en el conjunto de datos:
print("Cantidad de registros en el conjunto de datos de entrenamiento:", train_data.shape[0])
print("Cantidad de columnas en el conjunto de datos de entrenamiento:", train_data.shape[1])
# Out:
# Cantidad de registros en el conjunto de datos de entrenamiento: 59381
# Cantidad de columnas en el conjunto de datos de entrenamiento: 128

# %%
#Revisamos la distribución de los datos:
train_data.describe()
# Out:
#                  Id  Product_Info_1  Product_Info_3  Product_Info_4  \
# count  59381.000000    59381.000000    59381.000000    59381.000000
# mean   39507.211515        1.026355       24.415655        0.328952
# std    22815.883089        0.160191        5.072885        0.282562
# min        2.000000        1.000000        1.000000        0.000000
# 25%    19780.000000        1.000000       26.000000        0.076923
# 50%    39487.000000        1.000000       26.000000        0.230769
# 75%    59211.000000        1.000000       26.000000        0.487179
# max    79146.000000        2.000000       38.000000        1.000000
#
#        Product_Info_5  Product_Info_6  Product_Info_7       Ins_Age  \
# count    59381.000000    59381.000000    59381.000000  59381.000000
# mean         2.006955        2.673599        1.043583      0.405567
# std          0.083107        0.739103        0.291949      0.197190
# min          2.000000        1.000000        1.000000      0.000000
# ...

# %%
#Comprobamos si hay valores faltantes en el conjunto de datos:
train_data.isnull().sum()
# Out:
# Id                    0
# Product_Info_1        0
# Product_Info_2        0
# Product_Info_3        0
# Product_Info_4        0
#                      ..
# Medical_Keyword_45    0
# Medical_Keyword_46    0
# Medical_Keyword_47    0
# Medical_Keyword_48    0
# Response              0
# Length: 128, dtype: int64
